# %%
import numpy as np
import matplotlib
from matplotlib import pyplot as plt

# %%
import sys
import os

os.environ['WINGHOME'] = '/usr/local/lib/wingpro9'
sys.path.append(os.getenv('WINGHOME]'))

import wingdbstub
wingdbstub.Ensure()

# %% [markdown]
# # EEG topoplots

# %%
from gcpds.visualizations.topoplots import topoplot

# %%
channels = ['Fp1','Fpz','Fp2',
            'F7','F5','F3','F1','Fz','F2','F4','F6','F8',
            'C5','C3','C1','Cz','C2','C4','C6',
            'P7', 'P3','P1','Pz','P2','P4','P8',
            'O1','Oz','O2',
            'Iz']

data = np.random.normal(size=len(channels))

# %%
ax = topoplot(data, channels, contours=3, cmap='viridis_r')
plt.savefig('_images/topoplot.png')
ax.get_figure();
